# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up Exercises:
#
# Data Exploration and Understanding:
#
# • Dataset Overview:
#
# Load the dataset and display the first 10 rows.
#
# Identify the number of rows and columns in the dataset.
#
# List all the columns and their data types

# %%
#1. Load the dataset and display the first 10 rows.
file_path = "/content/drive/MyDrive/WHR-2024-5CS037.csv"
happiness_data = pd.read_csv(file_path)
happiness_data.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
#2. Identify the number of rows and columns in the dataset
num_rows, num_cols = happiness_data.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_cols}")
# Out:
# Number of rows: 143
# Number of columns: 9

# %%
#3. List all the columns and their data types
cols_info = happiness_data.dtypes
print("Column Information:\n", cols_info)
# Out:
# Column Information:
#  Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# • Basic Statistics:
#
# Calculate the mean, median, and standard deviation for the Score column.
#
# Identify the country with the highest and lowest happiness scores.

# %%
#1. Calculate the mean, median, and standard deviation for the Score column.
mean_score = happiness_data['score'].mean()
median_score = happiness_data['score'].median()
std_dev_score = happiness_data['score'].std()
print(f"Mean Score: {mean_score:.2f}")
print(f"Median Score: {median_score:.2f}")
print(f"Standard Deviation of Score: {std_dev_score:.2f}")
# Out:
# Mean Score: 5.53
# Median Score: 5.79
# Standard Deviation of Score: 1.17

# %%
#2. Identify the country with the highest and lowest happiness scores.
max_score = happiness_data['score'].max()
highest_score= happiness_data.loc[happiness_data['score'] == max_score, 'Country name'].values[0]
min_score = happiness_data['score'].min()
lowest_score = happiness_data.loc[happiness_data['score' ]== min_score, 'Country name'].values[0]
print(f"Country with the highest happiness score: {highest_score} ({max_score:.2f})")
print(f"Country with the lowest happiness score: {lowest_score} ({min_score:.2f})")
# Out:
# Country with the highest happiness score: Finland (7.74)
# Country with the lowest happiness score: Afghanistan (1.72)

# %% [markdown]
# Missing Values:
#
# Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
#1. Check if there are any missing values in the dataset. If so, display the total count for each column.
missing_values = happiness_data.isnull().sum()
print("Missing Values in WHR dataset: \n", missing_values)
# Out:
# Missing Values in WHR dataset:
#  Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
#
# Filter the dataset to show only the countries with a Score greater than 7.5.
#
# For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the top 10 rows.

# %%
#1. Filter the dataset to show only the countries with a Score greater than 7.5.
greater_score = happiness_data[happiness_data['score']>7.5]
print("Countries with a Score greater than 7.5:\n", greater_score)
# Out:
# Countries with a Score greater than 7.5:
#    Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %%
#2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the top 10 rows.
gdp_sorted = greater_score.sort_values(by='Log GDP per capita', ascending=False)
print("Top 10 counties by Log GDP per capita:\n", gdp_sorted.head(10))
# Out:
# Top 10 counties by Log GDP per capita:
#    Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# • Adding New Columns:
#
# Create a new column called Happiness Category that categorizes countries into three categories based on their Score:
#
# Low − (Score < 4)
#
# Medium − (4 ≤ Score ≤ 6)
#
# High − (Score > 6)

# %%
def categorize_happiness(score):
  if score < 4:
    return "Low"
  elif 4<= score <=6:
    return "Medium"
  else:
    return "High"
happiness_data['Happiness Category'] = happiness_data['score'].apply(categorize_happiness)
print(happiness_data[['Country name', 'score', 'Happiness Category']].head())
# Out:
#   Country name  score Happiness Category
# 0      Finland  7.741               High
# 1      Denmark  7.583               High
# 2      Iceland  7.525               High
# 3       Sweden  7.344               High
# 4       Israel  7.341               High

# %% [markdown]
# 2. Data Visualizations:
#
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
#
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.
#
# • Plot a histogram for the Score column to show its distribution and also interpret.
#
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
#Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
top_ten = happiness_data.nlargest(10, 'score')
plt.figure(figsize = (10, 5))
sns.barplot(x='Country name', y='score', data=top_ten)
plt.title('Top 10 Happiest Countries by Score')
plt.xlabel('Country')
plt.ylabel('Score')
plt.tight_layout()
plt.show()

# %%
#Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart
unhappy_ten = happiness_data.nsmallest(10, 'score')
plt.figure(figsize=(10, 5))
plt.plot(unhappy_ten['Country name'], unhappy_ten['score'], marker = 'o', linestyle = '-', color = 'red')
plt.title('Top 10 Unhappiest Countries by Score')
plt.xlabel('Country')
plt.ylabel('Score')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %%
#Histogram: Plot a histogram for the Score column to show its distribution and also interpret
plt.figure(figsize = (10,5))
sns.histplot(happiness_data['score'], bins = 20, kde = True)
plt.title('Distribution of Score column')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
#Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship
plt.figure(figsize = (10,5))
sns.scatterplot(x = 'Log GDP per capita', y ='score', data = happiness_data)
plt.title('Scatter Plot: Log GDP per capita VS Score')
plt.xlabel('Log GDP per capita')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# 3.2 Problem - 2 - Some Advance Data Exploration Task:
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
#1. Define the countries in South Asia
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# %%
#2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
south_asia_data = happiness_data[happiness_data['Country name'].isin(south_asian_countries)]
print("South Asian Countries Dataset: \n", south_asia_data)
# Out:
# South Asian Countries Dataset:
#      Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
#3.Save the filtered dataframe as separate CSV files for future use.
output_file = "South_Asia_WHR.csv"
south_asia_data.to_csv(output_file, index = False)
print(f"South Asian Countries Dataset saved to {output_file}")
# Out:
# South Asian Countries Dataset saved to South_Asia_WHR.csv

# %% [markdown]
# Task - 2 - Composite Score Ranking:
#
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
#1. Composite Score
south_asia_data['Composite Score'] = (
    0.40 * south_asia_data['Log GDP per capita'] + 0.30 * south_asia_data['Social support'] + 0.30 * south_asia_data['Healthy life expectancy']
)
print(south_asia_data[['Country name', 'Composite Score']])
# Out:
#     Country name  Composite Score
# 92         Nepal           0.8159
# 107     Pakistan           0.7039
# 125        India           0.7874
# 127    Sri Lanka           1.0739
# 128   Bangladesh           0.6774
# 142  Afghanistan           0.3238
# <ipython-input-29-4c12c8b47eaa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asia_data['Composite Score'] = (

# %%
#2. Rank the South Asian countries based on the Composite Score in descending order.
south_asia_rank = south_asia_data.sort_values(by = 'Composite Score', ascending = False)
print("South Asia Countries Dataset ranked by Composite Score in descending order: ", south_asia_rank[['Country name', 'Composite Score']])
# Out:
# South Asia Countries Dataset ranked by Composite Score in descending order:      Country name  Composite Score
# 127    Sri Lanka           1.0739
# 92         Nepal           0.8159
# 125        India           0.7874
# 107     Pakistan           0.7039
# 128   Bangladesh           0.6774
# 142  Afghanistan           0.3238

# %%
#3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
top_five = south_asia_rank.head(5)
plt.figure(figsize = (10, 5))
sns.barplot(x = 'Composite Score', y= 'Country name', data = top_five)
plt.title('Top 5 South Asian Countries by Composite Score')
plt.xlabel('Composite Score')
plt.ylabel('Country')
plt.show()

# %%
#4. Discuss whether the rankings based on the Composite Score align with the original Score - support your discussion with some visualization plot.
plt.figure(figsize = (10,5))
sns.scatterplot(x='Composite Score', y = 'score', data = south_asia_data, hue = 'Country name',s= 100)
plt.title('Comparison of Composite Score and Happiness Score')
plt.xlabel('Composite Score')
plt.ylabel('Happiness Score')
plt.show()

# %% [markdown]
# Task - 3 - Outlier Detection:
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
#1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
#2. Define outliers using the 1.5 × IQR rule.
q1_gdp, q3_gdp = south_asia_data['Log GDP per capita'].quantile([0.25, 0.75])
iqr_gdp = q3_gdp - q1_gdp
lower_gdp = q1_gdp - 1.5 * iqr_gdp
upper_gdp = q3_gdp + 1.5 * iqr_gdp
q1_score, q3_score = south_asia_data['score'].quantile([0.25, 0.75])
iqr_score = q3_score - q1_score
lower_score =q1_score - 1.5*iqr_score
upper_score = q3_score + 1.5*iqr_score
outliers = south_asia_data[(south_asia_data['Log GDP per capita']< lower_gdp) | (south_asia_data['Log GDP per capita']> upper_gdp) | (south_asia_data['score']<lower_score) | (south_asia_data['score']>upper_score)]
print("Outlier Countries in South Asia: \n", outliers)
# Out:
# Outlier Countries in South Asia:
#      Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628             0.0
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                           0.0       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness Category  \
# 142                      0.088                0.672                Low
#
#      Composite Score
# 142           0.3238

# %%
#3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers in a different color.
plt.figure(figsize = (10, 5))
sns.scatterplot(x= 'Log GDP per capita', y='score', data = south_asia_data, label ='Non-Outliers')
sns.scatterplot(x = 'Log GDP per capita', y = 'score', data = outliers, color ='red', label= 'Outliers')
plt.title('Scatter Plot of Log GDP per capita VS Score')
plt.xlabel('Log GDP per capita')
plt.ylabel('Score')
plt.legend()
plt.show()

# %% [markdown]
# Task - 4 - Exploring Trends Across Metrics: Tasks:
#
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation {pearson correlation} with the Score for South Asian countries.
#
# 2. Create scatter plots with trendlines for these metrics against the Score.
#
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for South Asian countries.

# %%
#1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation {pearson correlation} with the Score for South Asian countrie
correlation_freedom = south_asia_data['Freedom to make life choices'].corr(south_asia_data['score'])
correlation_generosity = south_asia_data['Generosity'].corr(south_asia_data['score'])
print(f"Correlation between Freedom to make life choices and Score: {correlation_freedom:.2f}")
print(f"Correlation between Generosity and Score: {correlation_generosity:.2f}")
# Out:
# Correlation between Freedom to make life choices and Score: 0.80
# Correlation between Generosity and Score: 0.87

# %%
#2. Create scatter plots with trendlines for these metrics against the Score.
plt.figure(figsize = (10, 5))
sns.regplot(x ='Freedom to make life choices', y = 'score', data = south_asia_data, color ='blue',line_kws={'color': 'red'})
plt.title('Scatter Plot of Freedom to make life choices VS Score')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Score')
plt.show()

plt.figure(figsize = (10,5))
sns.regplot(x ='Generosity', y = 'score', data= south_asia_data, color = 'red', line_kws = {'color':'green'})
plt.title('Scatter Plot of Generosity VS Score')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# Task - 5 - Gap Analysis:
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
#1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score for each South Asian country.
south_asia_data['GDP-Score Gap'] = south_asia_data['Log GDP per capita'] - south_asia_data['score']
print(south_asia_data[['Country name', 'Log GDP per capita', 'score', 'GDP-Score Gap']])
# Out:
#     Country name  Log GDP per capita  score  GDP-Score Gap
# 92         Nepal               0.965  5.158         -4.193
# 107     Pakistan               1.069  4.657         -3.588
# 125        India               1.166  4.054         -2.888
# 127    Sri Lanka               1.361  3.898         -2.537
# 128   Bangladesh               1.122  3.886         -2.764
# 142  Afghanistan               0.628  1.721         -1.093
# <ipython-input-47-23dedba5cfec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asia_data['GDP-Score Gap'] = south_asia_data['Log GDP per capita'] - south_asia_data['score']

# %%
#2. Rank the South Asian countries by this gap in both ascending and descending order.
ascending_gap = south_asia_data.sort_values(by ='GDP-Score Gap', ascending = True)
descending_gap = south_asia_data.sort_values(by = 'GDP-Score Gap', ascending = False)
print("Ascending order:\n", ascending_gap)
print("Descending order:\n", descending_gap)
# Out:
# Ascending order:
#      Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 128   Bangladesh  3.886               1.122           0.249
# 127    Sri Lanka  3.898               1.361           1.179
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 128                    0.513                         0.775       0.140
# 127                    0.586                         0.583       0.144
# 142                    0.242                         0.000       0.091
#
# ...

# %%
#3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
top_Lthree_positive = ascending_gap.head(3)
top_Lthree_negative = descending_gap.head(3)
plt.figure(figsize=(10, 5))
sns.barplot(x='GDP-Score Gap', y = 'Country name', data= top_Lthree_positive, color = 'green')
plt.title('Top 3 Countries with Largest Negaitive Gaps')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country')
plt.show()

plt.figure(figsize = (10, 5))
sns.barplot(x = 'GDP-Score Gap', y = 'Country name', data = top_Lthree_negative, color = 'red')
plt.title('Top 3 Countries with Largest Positive Gaps')
plt.xlabel('Country')
plt.ylabel('GDP-Score Gap')
plt.show()

# %% [markdown]
# 3.3 Problem - 3 - Comparative Analysis:
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#
# "United Arab Emirates", "Yemen"]

# %%
#1. Middle Eastern Countries Dataset
middle_eastern_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan",
"Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
"United Arab Emirates", "Yemen"]
middle_east_data = happiness_data[happiness_data['Country name'].isin(middle_eastern_countries)]
middle_east_data.to_csv("Middle_East_WHR.csv", index = False)
print("Middle Eastern Countries Dataset has been saved.")
# Out:
# Middle Eastern Countries Dataset has been saved.

# %% [markdown]
# 1. Descriptive Statistics:
#
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
#
# • Which region has higher happiness Scores on average?

# %%
#Mean, Standard Deviation of both South Asia and Middle East
mean_sa = south_asia_data['score'].mean()
std_sa = south_asia_data['score'].std()
mean_me = middle_east_data['score'].mean()
std_me = middle_east_data['score'].std()
print(f"Mean and Standard Deviation of South Asia:\n Mean: {mean_sa:.2f}, Standard Deviation: {std_sa:.2f}")
print(f"Mean and Standard Deviation of Middle East:\n Mean: {mean_me:.2f}, Standard Deviation: {std_me:.2f}")
# Out:
# Mean and Standard Deviation of South Asia:
#  Mean: 3.90, Standard Deviation: 1.18
# Mean and Standard Deviation of Middle East:
#  Mean: 5.41, Standard Deviation: 1.57

# %%
#Which region has higher happiness Scores on average?
higher_score = "South Asia" if mean_sa > mean_me else "Middle East"
print(f"The region with higher happiness scores on average is {higher_score}.")
# Out:
# The region with higher happiness scores on average is Middle East.

# %% [markdown]
# 2. Top and Bottom Performers:
#
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
#Identify the top 3 and bottom 3 countries in each region based on the score.
top_sa = south_asia_data.nlargest(3, 'score')
bottom_sa = south_asia_data.nsmallest(3, 'score')
top_me = middle_east_data.nlargest(3, 'score')
bottom_me = middle_east_data.nsmallest(3, 'score')
print(f"Top 3 countries of South Asia: \n {top_sa}, Bottom 3 countries of South Asia: \n {bottom_sa}")
print(f"Top 3 countries of Middle East: \n {top_me}, Bottom 3 countries of Middle East: \n {bottom_me}")
# Out:
# Top 3 countries of South Asia:
#      Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
#
#      Perceptions of corruption  Dystopia + residual Happiness Category  \
# 92                       0.115                1.783             Medium
# 107                      0.074                1.907             Medium
# 125                      0.122                0.756             Medium
#
#      Composite Score  GDP-Score Gap
# 92            0.8159         -4.193
# 107           0.7039         -3.588
# ...

# %%
#Plot bar charts comparing these charts
top_bottom_data = pd.concat([top_sa.assign(Region = 'South Asia'), bottom_sa.assign(Region = 'South Asia'), top_me.assign(Region = 'Middle East'), bottom_me.assign(Region = 'Middle East')])
plt.figure(figsize = (10, 5))
sns.barplot(x = 'score', y ='Country name', data = top_bottom_data, hue = 'Region')
plt.title('Top 3 and Bottom 3 Countries by Score')
plt.xlabel('Score')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# 3. Metric Comparisons:
#
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
#
# • Which metrics show the largest disparity between the two regions?

# %%
#• Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy between the regions using grouped bar charts.
key_metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
mean_sa = south_asia_data[key_metrics].mean()
mean_me = middle_east_data[key_metrics].mean()
comparison_df = pd.DataFrame({'Region: \n South Asia': mean_sa, 'Region: \n Middle East': mean_me}).reset_index().rename(columns ={'index': 'Metric'})
plt.figure(figsize=(10, 5))
comparison_df.plot(kind='bar', x='Metric', figsize=(12, 6))
plt.title('Key Metric Comparisons between South Asia and Middle East')
plt.xlabel('Metric')
plt.ylabel('Mean Value')
plt.xticks(rotation=0)
plt.show()

# %%
#• Which metrics show the largest disparity between the two regions?
disparities = abs(mean_sa - mean_me)
largest_disparity = disparities.idxmax()
print(f"The largest disparity is in: {largest_disparity}")
# Out:
# The largest disparity is in: Social support

# %% [markdown]
# 4. Happiness Disparity:
#
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
# • Which region has greater variability in happiness?

# %%
# Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
range_sa = south_asia_data['score'].max()-south_asia_data['score'].min()
range_me = middle_east_data['score'].max() - middle_east_data['score'].min()
cv_sa = south_asia_data['score'].std() / south_asia_data['score'].mean()
cv_me = middle_east_data['score'].std() / middle_east_data['score'].mean()
print(f"South Asia:\n Range: {range_sa:.2f}, CV: {cv_sa:.2f}")
print(f"Middle East:\n Range: {range_me:.2f}, CV: {cv_me:.2f}")
# Out:
# South Asia:
#  Range: 3.44, CV: 0.30
# Middle East:
#  Range: 4.63, CV: 0.29

# %% [markdown]
# 5. Correlation Analysis:
#
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and Generosity within each region.
#
# • Create scatter plots to visualize and interpret the relationships.

# %%
# Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and Generosity within each region.
corr_freedom_sa = south_asia_data['Freedom to make life choices'].corr(south_asia_data['score'])
corr_freedom_me = middle_east_data['Freedom to make life choices'].corr(middle_east_data['score'])
corr_generosity_sa = south_asia_data['Generosity'].corr(south_asia_data['score'])
corr_generosity_me = middle_east_data['Generosity'].corr(middle_east_data['score'])
print(f"South Asia:\n Freedom Correlation: {corr_freedom_sa:.2f}, Geneoristy Correlation: {corr_generosity_me:.2f}")
print(f"Middle East:\n Freedom Correlation: {corr_freedom_me:.2f}, Geneoristy Correlation: {corr_generosity_me:.2f}")
# Out:
# South Asia:
#  Freedom Correlation: 0.80, Geneoristy Correlation: 0.63
# Middle East:
#  Freedom Correlation: 0.86, Geneoristy Correlation: 0.63

# %%
#Create scatter plots to visualize and interpret the relationships.
plt.figure(figsize = (12,6))
plt.subplot(1, 2, 1)
sns.scatterplot(x = 'Freedom to make life choices', y = 'score', data = south_asia_data)
plt.title('South Asia: Freedom to make life choices VS Score')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Score')

plt.subplot(1, 2, 2)
sns.scatterplot(x = 'Generosity', y = 'score', data = south_asia_data)
plt.title('Soouth Asia: Generosity VS Score')
plt.xlabel('Generosity')

plt.figure(figsize = (12,6))
plt.subplot(1, 2,1)
sns.scatterplot(x = 'Freedom to make life choices', y = 'score', data = middle_east_data)
plt.title('Middle East: Freedom to make life choices VS Score')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Score')

plt.subplot(1, 2, 2)
sns.scatterplot(x = 'Generosity', y = 'score', data = middle_east_data)
plt.title('Middle East: Generosity VS Score')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# Outlier Detection:
#
# • Identify outlier countries in both regions based on Score and GDP per Capita.
#
# • Plot these outliers and discuss their implications.

# %%
#• Identify outlier countries in both regions based on Score and GDP per Capita.
def detect_outliers(df, column):
  q1, q3 = df[column].quantile([0.25, 0.75])
  iqr = q3 - q1
  lower_bound = q1 - 1.5 * iqr
  upper_bound = q3 + 1.5 * iqr
  return df[(df[column] < lower_bound) | (df[column]> upper_bound)]

outliers_sa = detect_outliers(south_asia_data, 'score')
outliers_me = detect_outliers(middle_east_data, 'score')

print("South Asia Outliers:", outliers_sa)
print("Middle East Outliers:", outliers_me)
# Out:
# South Asia Outliers:     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628             0.0
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                           0.0       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness Category  \
# 142                      0.088                0.672                Low
#
#      Composite Score  GDP-Score Gap
# 142           0.3238         -1.093
# Middle East Outliers: Empty DataFrame
# Columns: [Country name, score, Log GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption, Dystopia + residual, Happiness Category]
# Index: []

# %%
#Plot these outliers and discuss their implications.
plt.figure(figsize = (10, 5))
sns.scatterplot(x = 'Log GDP per capita', y = 'score', data = south_asia_data, label ='South Asia')
sns.scatterplot(x = 'Log GDP per capita', y = 'score', data = middle_east_data, label = 'Middle East')
sns.scatterplot(x = 'Log GDP per capita', y = 'score', data = outliers_sa, color = 'red', label = 'South Asia Outliers')
sns.scatterplot(x = 'Log GDP per capita', y = 'score', data = outliers_me, color = 'red', label = 'Middle East Outliers')
plt.title('Outliers in South Asia and Middle East')
plt.legend()
plt.show()

# %% [markdown]
# 7. Visualization:
#
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
#Boxplot
plt.figure(figsize = (10, 5))
sns.boxplot(x = 'Region', y='score', data = pd.concat([south_asia_data.assign(Region = 'South Asia'), middle_east_data.assign(Region = 'Middle East')]))
plt.title('Boxplot Comparison: Score Distribution\n South Asia VS Middle East')
plt.show()
